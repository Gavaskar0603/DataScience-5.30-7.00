# %%
import pandas as pd

# %%
d={
    "Name":["Kishore","Karthick","Pavithran","Bhaviya","Hari"],
    "Salary":[18000,20000,22000,25000,30000]
}
d
# Out:
# {'Name': ['Kishore', 'Karthick', 'Pavithran', 'Bhaviya', 'Hari'],
#  'Salary': [18000, 20000, 22000, 25000, 30000]}

# %%
df = pd.DataFrame(d)
df
# Out:
#         Name  Salary
# 0    Kishore   18000
# 1   Karthick   20000
# 2  Pavithran   22000
# 3    Bhaviya   25000
# 4       Hari   30000

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(d["Name"],d["Salary"])
plt.title("Name By Salary")
plt.xlabel("Name")
plt.ylabel("Salary")
plt.show()

# %%
d1=pd.read_csv("student_performance.csv")
d1
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 0                1                     18.5                   95.6
# 1                2                     14.0                   80.0
# 2                3                     19.5                   86.3
# 3                4                     25.7                   70.2
# 4                5                     13.4                   81.9
# ...            ...                      ...                    ...
# 999995      999996                     18.0                   95.5
# 999996      999997                     15.7                   82.7
# 999997      999998                     14.2                   85.1
# 999998      999999                     25.3                   90.0
# 999999     1000000                     18.3                   84.6
#
#         class_participation  total_score grade
# 0                       3.8         97.9     A
# 1                       2.5         83.9     B
# ...

# %%
d1.columns[d1.isna().any()]
# Out:
# Index([], dtype='object')

# %%
d1.columns
# Out:
# Index(['student_id', 'weekly_self_study_hours', 'attendance_percentage',
#        'class_participation', 'total_score', 'grade'],
#       dtype='object')

# %%
d1.groupby("grade")[["total_score","weekly_self_study_hours"]].mean().plot(kind="bar")
plt.title("Total score by Study hours")
plt.xlabel("Grade")
plt.ylabel("Total score")
plt.show()

# %%
c=["Kitkat","Diarymilk","5star","Dark Fantasy"]
s=[100,80,150,130]
plt.bar(c,s,color=["red","blue","yellow","black"])
plt.show()

# %%
plt.bar(d["Name"],d["Salary"],color=["red","blue","green","black","yellow"])
plt.title("Name By Salary")
plt.xlabel("Name")
plt.ylabel("Salary")
plt.show()

# %%
#Frequency of a value
mark = [45,48,56,68,55,59,72,96,85]
plt.hist(mark)
plt.show()

# %%
plt.hist(d1["total_score"],bins=20)
plt.show()

# %%
#used for trend analysis
plt.plot(c,s,color="red")
plt.show()

# %%
#used for contribution
d1["grade"].value_counts().plot(kind="pie",autopct="%1.0f%%")
plt.show()

# %%
import numpy as np

# %%
a=np.array([10,20,30,80,45,60])
np.mean(a)
# Out:
# np.float64(40.833333333333336)

# %%
np.median(a)
# Out:
# np.float64(37.5)

# %%
#to find the outliers you can use boxplot

plt.boxplot([d1["weekly_self_study_hours"],d1["total_score"]])
plt.show()

# %%
np.mean(d1["total_score"])
# Out:
# np.float64(84.2838453)

# %%
np.median(d1["total_score"])
# Out:
# np.float64(87.5)
