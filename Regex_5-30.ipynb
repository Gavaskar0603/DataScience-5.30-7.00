# %%
import re

# %%
a="Hello this is Data Science class and you can contact this number 7894561230"
re.findall("\d+",a)
# Out:
# ['7894561230']

# %%
re.search("Data Science",a)
# Out:
# <re.Match object; span=(14, 26), match='Data Science'>

# %%
c1 = re.sub("a","**",a)
c1
# Out:
# 'Hello this is D**t** Science cl**ss **nd you c**n cont**ct this number 7894561230'

# %%
c= re.match(r"Hello",a)
c.group()
# Out:
# 'Hello'

# %%
a="Hello this is Data Science class and you can contact this number 7894561230"
re.findall("\D",a)
# Out:
# ['H',
#  'e',
#  'l',
#  'l',
#  'o',
#  ' ',
#  't',
#  'h',
#  'i',
#  's',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'D',
#  'a',
#  't',
#  'a',
#  ' ',
#  'S',
#  'c',
#  'i',
#  'e',
#  'n',
#  'c',
#  'e',
#  ' ',
#  'c',
#  'l',
#  'a',
#  's',
#  's',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  'y',
#  'o',
#  'u',
#  ' ',
#  'c',
#  'a',
#  'n',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'a',
#  'c',
#  't',
#  ' ',
#  't',
#  'h',
#  'i',
#  's',
#  ' ',
#  'n',
#  'u',
#  'm',
#  'b',
#  'e',
#  'r',
#  ' ']

# %%
a="Hello this is Data Science class and you can contact this number 7894561230"
re.findall("\s",a)
# Out:
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']

# %%
a="Hello this is Data Science class and you can contact this number 7894561230"
re.findall("\S+",a)
# Out:
# ['Hello',
#  'this',
#  'is',
#  'Data',
#  'Science',
#  'class',
#  'and',
#  'you',
#  'can',
#  'contact',
#  'this',
#  'number',
#  '7894561230']

# %%
a="Hello this is Data Science class and you can contact this number 7894561230"
re.findall("^Da",a)
# Out:
# []
